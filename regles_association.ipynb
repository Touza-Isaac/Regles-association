# %% [markdown]
# <a href="https://colab.research.google.com/github/Touza-Isaac/Regles-association/blob/main/regles_association.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# %%
# Charger les données
data = [['Lait', 'Pain','Beurre'],
        ['Lait', 'Pain', 'Œufs'],
        ['Lait', 'Pain', 'Beurre', 'Œufs'],
        ['Lait', 'Pain', 'Jus orange'],
        ['Pain', 'Beurre'],
        ['Lait', 'Œufs'],
        ['Lait', 'Pain', 'Beurre'],
        ['Pain', 'Jus orange'],
        ['Lait', 'Pain', 'Beurre', 'Œufs'],
        ['Lait', 'Pain', 'Jus orange']]

# %%
data
# Out:
# [['Lait', 'Pain', 'Beurre'],
#  ['Lait', 'Pain', 'Œufs'],
#  ['Lait', 'Pain', 'Beurre', 'Œufs'],
#  ['Lait', 'Pain', 'Jus orange'],
#  ['Pain', 'Beurre'],
#  ['Lait', 'Œufs'],
#  ['Lait', 'Pain', 'Beurre'],
#  ['Pain', 'Jus orange'],
#  ['Lait', 'Pain', 'Beurre', 'Œufs'],
#  ['Lait', 'Pain', 'Jus orange']]

# %%
# Encoder les transactions
te = TransactionEncoder()
te_ary = te.fit_transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#    Beurre  Jus orange   Lait   Pain   Œufs
# 0    True       False   True   True  False
# 1   False       False   True   True   True
# 2    True       False   True   True   True
# 3   False        True   True   True  False
# 4    True       False  False   True  False
# 5   False       False   True  False   True
# 6    True       False   True   True  False
# 7   False        True  False   True  False
# 8    True       False   True   True   True
# 9   False        True   True   True  False

# %%
# Extraire les articles fréquents
frequent_items = apriori(df, min_support=0.2, use_colnames=True)

# %%
frequent_items
# Out:
#     support                    itemsets
# 0       0.5                    (Beurre)
# 1       0.3                (Jus orange)
# 2       0.8                      (Lait)
# 3       0.9                      (Pain)
# 4       0.4                      (Œufs)
# 5       0.4              (Lait, Beurre)
# 6       0.5              (Pain, Beurre)
# 7       0.2              (Beurre, Œufs)
# 8       0.2          (Lait, Jus orange)
# 9       0.3          (Pain, Jus orange)
# 10      0.7                (Lait, Pain)
# 11      0.4                (Lait, Œufs)
# 12      0.3                (Pain, Œufs)
# 13      0.4        (Lait, Pain, Beurre)
# 14      0.2        (Lait, Beurre, Œufs)
# 15      0.2        (Pain, Beurre, Œufs)
# 16      0.2    (Lait, Pain, Jus orange)
# 17      0.3          (Lait, Pain, Œufs)
# 18      0.2  (Lait, Pain, Beurre, Œufs)

# %%
 # Extraire les règles d'association
rules = association_rules(frequent_items, metric="confidence", min_threshold=0.7)

# %%
rules
# Out:
#              antecedents   consequents  antecedent support  \
# 0               (Beurre)        (Lait)                 0.5
# 1               (Beurre)        (Pain)                 0.5
# 2           (Jus orange)        (Pain)                 0.3
# 3                 (Lait)        (Pain)                 0.8
# 4                 (Pain)        (Lait)                 0.9
# 5                 (Œufs)        (Lait)                 0.4
# 6                 (Œufs)        (Pain)                 0.4
# 7         (Lait, Beurre)        (Pain)                 0.4
# 8         (Pain, Beurre)        (Lait)                 0.5
# 9               (Beurre)  (Lait, Pain)                 0.5
# 10        (Beurre, Œufs)        (Lait)                 0.2
# 11        (Beurre, Œufs)        (Pain)                 0.2
# 12    (Lait, Jus orange)        (Pain)                 0.2
# 13          (Lait, Œufs)        (Pain)                 0.4
# 14          (Pain, Œufs)        (Lait)                 0.3
# ...

# %%
# Afficher les règles et leurs confiances
for _, rule in rules.iterrows():
    antecedent = ', '.join(list(rule['antecedents']))
    consequent = ', '.join(list(rule['consequents']))
    confidence = rule['confidence']
    print(f"Règle: {antecedent} -> {consequent}")
    print(f"Confiance: {confidence}\n")
# Out:
# Règle: Beurre -> Lait
# Confiance: 0.8
#
# Règle: Beurre -> Pain
# Confiance: 1.0
#
# Règle: Jus orange -> Pain
# Confiance: 1.0
#
# Règle: Lait -> Pain
# Confiance: 0.8749999999999999
#
# Règle: Pain -> Lait
# Confiance: 0.7777777777777777
#
# Règle: Œufs -> Lait
# Confiance: 1.0
#
# Règle: Œufs -> Pain
# Confiance: 0.7499999999999999
#
# Règle: Lait, Beurre -> Pain
# Confiance: 1.0
#
# Règle: Pain, Beurre -> Lait
# Confiance: 0.8
#
# Règle: Beurre -> Lait, Pain
# Confiance: 0.8
#
# Règle: Beurre, Œufs -> Lait
# Confiance: 1.0
#
# Règle: Beurre, Œufs -> Pain
# Confiance: 1.0
#
# Règle: Lait, Jus orange -> Pain
# Confiance: 1.0
#
# Règle: Lait, Œufs -> Pain
# Confiance: 0.7499999999999999
#
# Règle: Pain, Œufs -> Lait
# Confiance: 1.0
#
# Règle: Œufs -> Lait, Pain
# Confiance: 0.7499999999999999
#
# Règle: Lait, Beurre, Œufs -> Pain
# Confiance: 1.0
#
# Règle: Pain, Beurre, Œufs -> Lait
# Confiance: 1.0
#
# Règle: Beurre, Œufs -> Lait, Pain
# Confiance: 1.0
